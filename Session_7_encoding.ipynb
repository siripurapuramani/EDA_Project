# %% [markdown]
# - Before Model development
#
# - We will do EDA : Exploratry data analysis
#
# - Features(columns) analysis
#
#      - Categorical, Numerical, Outlier anaysis, Bivariate, Multivariate
#
#      - We will get the insights
#
# - Feature Engineering
#
#       - We will modify the data
#
#       - Models developed by maths
#
#       - Encoding : Convert categorical data to Numerical Variables
#
#       - Scaling : All the numerical columns makes under one scale
#
#       - Transformations : All the maths developed by assumption data follows Normal distribution
#
#             - Convert skewed distribution or Normal
#
# - Feature Selection

# %%
import pandas as pd
visa_df=pd.read_csv(r"C:\Users\ACER\Downloads\Visadataset.csv")

# %%
types=visa_df.dtypes.to_dict()
cat=[i for i,j in types.items() if j=='object']
num=[i for i,j in types.items() if j!='object']

# %%
cat =visa_df.select_dtypes(include='object').columns
num =visa_df.select_dtypes(exclude='object').columns

# %%
visa_df['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %% [markdown]
# **Map Method**
#
# - Create a dictionary lables as keys,numbers as values
#
# - in python index start with 0
#
# - case status has two lables we need two values 0 and 1
#
# - Certified becomes 0
#
# - Denied becomes 1

# %%
visa_df['case_status'].nunique()
# Out:
# 2

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0,'Denied':1}
visa_df['case_status']=visa_df['case_status'].map(d)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
labels=visa_df['continent'].unique()
labels
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
num1=visa_df['continent'].nunique()

# %%
visa_df=pd.read_csv(r"C:\Users\ACER\Downloads\Visadataset.csv")
labels=visa_df['continent'].unique()
d1={}
for i in range(len(labels)):
    d1[labels[i]]=i
visa_df['continent']=visa_df['continent'].map(d1)

# %%
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          1              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\ACER\Downloads\Visadataset.csv")
labels=visa_df['case_status'].unique()
d1={labels[i]:i for i in range (len(labels))}
visa_df['case_status']=visa_df['case_status'].map(d1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\ACER\Downloads\Visadataset.csv")
for i in cat[1:] :
    labels=visa_df[i].unique()
    d1={labels[i]:i for i in range (len(labels))}
    visa_df[i]=visa_df[i].map(d1)
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          0                      0                   0
# 1         EZYV02          0                      1                   1
# 2         EZYV03          0                      2                   0
# 3         EZYV04          0                      2                   0
# 4         EZYV05          1                      1                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          0                      2                   1
# 25476  EZYV25477          0                      0                   1
# 25477  EZYV25478          0                      1                   1
# 25478  EZYV25479          0                      1                   1
# 25479  EZYV25480          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# **LabelEncoder**
#
# - Sickit-learn(sklearn)
#
# - Sklearn library is a heart of machine learning in python
#
# - MLlib is heart of machine learning in pyspark
#
# - sklearn(Library)
#
#         - preprocess(Class)
#
#             - LabelEncoder(method)
#
# - fit : calculate something
#
# - fit_transform : we are modify the values because of calculated one

# %%
visa_df=pd.read_csv(r"C:\Users\ACER\Downloads\Visadataset.csv")

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder  #read the method
le=LabelEncoder() #save the method
le.fit_transform(visa_df['case_status'])
# Out:
# array([1, 0, 1, ..., 0, 0, 0], shape=(25480,))

# %% [markdown]
# **OneHotEncoder**

# %% [markdown]
# |Case_status|Case_status_Denied|Case_status_Certified|
# |-|-|-|
# |Denied|1|0|
# |Certified|1|0|

# %% [markdown]
# - OneHotEncoder creates new columns that equal to number of unique labels
#
# - One Disadvantage is data dimensions will be increased
#
# - More Dimentions leads to more processing time leads to bigger infra memory
#
# - This is called as **Curse of dimentionality**
#
# **Advantages**
#
#     - Generally  ML algorithms Excpects no correlation between input columns
#
#     - When one column value avaiable and at a same time another column value not avaiable means
#
#     - both are independent each other

# %%
#pd.get_dummies(visa_df,columns=cat) wrong
pd.get_dummies(visa_df,columns=cat[1:])
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage  \
# 0         EZYV01            14513         2007         592.2029
# 1         EZYV02             2412         2002       83425.6500
# 2         EZYV03            44444         2008      122996.8600
# 3         EZYV04               98         1897       83434.0300
# 4         EZYV05             1082         2005      149907.3900
# ...          ...              ...          ...              ...
# 25475  EZYV25476             2601         2008       77092.5700
# 25476  EZYV25477             3274         2006      279174.7900
# 25477  EZYV25478             1121         1910      146298.8500
# 25478  EZYV25479             1918         1887       86154.7700
# 25479  EZYV25480             3195         1960       70876.9100
#
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                 False            True             False
# 1                 False            True             False
# ...

# %%
pd.get_dummies(visa_df,columns=cat[1:],dtype=int)
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage  \
# 0         EZYV01            14513         2007         592.2029
# 1         EZYV02             2412         2002       83425.6500
# 2         EZYV03            44444         2008      122996.8600
# 3         EZYV04               98         1897       83434.0300
# 4         EZYV05             1082         2005      149907.3900
# ...          ...              ...          ...              ...
# 25475  EZYV25476             2601         2008       77092.5700
# 25476  EZYV25477             3274         2006      279174.7900
# 25477  EZYV25478             1121         1910      146298.8500
# 25478  EZYV25479             1918         1887       86154.7700
# 25479  EZYV25480             3195         1960       70876.9100
#
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                     0               1                 0
# 1                     0               1                 0
# ...

# %% [markdown]
# - If data is on ordinal go with LabelEncoder
#
# - If data is Nominal go with OneHotEncoder
#
# - If Labels are more go with LabelEncoder
#
# - If Labels are
